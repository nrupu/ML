# %% [markdown]
# <a href="https://colab.research.google.com/github/nrupu/ML/blob/main/ML0002.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/Iris.csv') #read csv file ,copy paste the path
df #to show the table
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# explore the data frame like summary in R
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
#basic inform
df.head(2)#first five default
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa

# %%
df.tail(2)#default five
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica

# %%
df.shape #keyword no of row,colum
df.columns #display column as list
df.dtypes #keyword to show datatype object (string)
df.info()#function to summary the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
#datacleaning
df.isnull()#display the whole dataset
df.isnull().sum()
e
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
#duplicate
df.duplicated()#whole set
df.duplicated().sum()#just parts
# Out:
# np.int64(0)

# %%
df.drop('Id',axis=1,inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-3605948350> in <cell line: 0>()
# ----> 1 df.drop('Id',axis=1,inplace=True)
#       2 df
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
# Based on typical Iris dataset column names, let's assume they are 'SepalLengthCm' and 'SepalWidthCm'.
# If df.columns output shows different names, replace them in the scatterplot call.
sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm', data=df, hue='Species')
plt.legend(bbox_to_anchor=(1, 1), loc=2)

# %%
sns.scatterplot(x='PetalLengthCm', y='PetalWidthCm', data=df, hue='Species')
plt.legend(bbox_to_anchor=(1, 1), loc=2)

# %%
sns.pairplot(hue='Species',data=df)

# %%
df.groupby('Species')['SepalLengthCm'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Species'>

# %%
df.groupby('Species')['SepalWidthCm'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Species'>

# %%
df.groupby('Species')['PetalLengthCm'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Species'>

# %%
df.groupby('Species')['PetalWidthCm'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Species'>

# %%
plt.figure()
df['SepalLengthCm'].plot(kind='hist',color='skyblue',edgecolor='black')
plt.title('SepalLengthCm')
plt.xlabel('SepalLengthCm')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.figure()
df['SepalWidthCm'].plot(kind='hist',color='green',edgecolor='black')
plt.title('SepalWidthCm')
plt.xlabel('SepalWidthCm')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.figure()
df['PetalLengthCm'].plot(kind='hist',color='red',edgecolor='black')
plt.title('PetalLengthCm')
plt.xlabel('PetalLengthCm')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.figure()#inside this we can design length
df['PetalWidthCm'].plot(kind='hist',color='blue',edgecolor='black')
plt.title('PetalWidthCm')
plt.xlabel('PetalWidthCm')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
sns.heatmap(df.select_dtypes(("number")).corr(method='pearson'),annot=True)
# Out:
# <Axes: >

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Species']=le.fit_transform(df['Species'])
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0              5.1           3.5            1.4           0.2        0
# 1              4.9           3.0            1.4           0.2        0
# 2              4.7           3.2            1.3           0.2        0
# 3              4.6           3.1            1.5           0.2        0
# 4              5.0           3.6            1.4           0.2        0
# ..             ...           ...            ...           ...      ...
# 145            6.7           3.0            5.2           2.3        2
# 146            6.3           2.5            5.0           1.9        2
# 147            6.5           3.0            5.2           2.0        2
# 148            6.2           3.4            5.4           2.3        2
# 149            5.9           3.0            5.1           1.8        2
#
# [150 rows x 5 columns]

# %%
#split and testing y(out),training X(in)
X=df.drop('Species',axis=1)
y=df['Species']

# %%
#train and test data
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=33)

# %% [markdown]
# SVM (SVC) hyperplane (support vector machine/classification)
# find the point wherethe unique feature find.disadvantage(can't use in large data set)not like linear regression it can curve.use case text,image classification.
# 2)KNN image classification(lazy algorithm)
# 3)Decision Tree (dis advantagein small dataset)appli:medical analysis

# %%
from sklearn.metrics import accuracy_score,classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train,y_train)
knn_grade=knn.predict(X_test)



print('Accurancy= ',accuracy_score(y_test,knn_grade))
target_names=['setosa','versicolor','virginica']
print(classification_report(y_test,knn_grade,target_names=target_names))
# Out:
# Accurancy=  0.9666666666666667
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00         8
#   versicolor       0.89      1.00      0.94         8
#    virginica       1.00      0.93      0.96        14
#
#     accuracy                           0.97        30
#    macro avg       0.96      0.98      0.97        30
# weighted avg       0.97      0.97      0.97        30

# %%
#SVc
svc=SVC()
svc.fit(X_train,y_train)
svc_grade=svc.predict(X_test)
print('Accurancy= ',accuracy_score(y_test,svc_grade))

target_names=['setosa','versicolor','virginica']
print(classification_report(y_test,svc_grade,target_names=target_names))
# Out:
# Accurancy=  0.9
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00         8
#   versicolor       0.73      1.00      0.84         8
#    virginica       1.00      0.79      0.88        14
#
#     accuracy                           0.90        30
#    macro avg       0.91      0.93      0.91        30
# weighted avg       0.93      0.90      0.90        30

# %%
#decision tree
tree=DecisionTreeClassifier()
tree.fit(X_train,y_train)
tree_grade=tree.predict(X_test)
print('Accurancy= ',accuracy_score(y_test,tree_grade))
print(classification_report(y_test,tree_grade,target_names=target_names))
# Out:
# Accurancy=  0.8666666666666667
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00         8
#   versicolor       0.67      1.00      0.80         8
#    virginica       1.00      0.71      0.83        14
#
#     accuracy                           0.87        30
#    macro avg       0.89      0.90      0.88        30
# weighted avg       0.91      0.87      0.87        30

# %%
#logistic algorithm ,random forest

# %% [markdown]
#  which predicts **continuous values** it predicts the probability that an input belongs to a specific class.
#
#  Logistic regression uses sigmoid function or logistic function which is a complex cost function. This
# sigmoid function is used to model the data in logistic regression. The function can be represented as:
#
# 1/1+e^-x
#
# o f(x)= Output between the 0 and 1 value.
#
# o x= input to the function
#
# o e= base of natural logarithm.
#
# Binomial Logistic Regression:
# Multinomial Logistic Regression:
# Ordinal Logistic Regression:
#
# A random forest is an ensemble learning method where multiple decision trees are constructed
# and then they are merged to get a more accurate prediction.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
log=LogisticRegression()#if optimal solution not get in the
log.fit(X_train,y_train)
log_grade=log.predict(X_test)
print('Accurancy= ',accuracy_score(y_test,log_grade))

print(classification_report(y_test,log_grade,target_names=target_names))
# Out:
# Accurancy=  0.9333333333333333
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00         8
#   versicolor       0.80      1.00      0.89         8
#    virginica       1.00      0.86      0.92        14
#
#     accuracy                           0.93        30
#    macro avg       0.93      0.95      0.94        30
# weighted avg       0.95      0.93      0.93        30

# %%
rand=RandomForestClassifier(120)
rand.fit(X_train,y_train)
rand_grade=rand.predict(X_test)
print('Accurancy= ',accuracy_score(y_test,rand_grade))

print(classification_report(y_test,rand_grade,target_names=target_names))
# Out:
# Accurancy=  0.9
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00         8
#   versicolor       0.73      1.00      0.84         8
#    virginica       1.00      0.79      0.88        14
#
#     accuracy                           0.90        30
#    macro avg       0.91      0.93      0.91        30
# weighted avg       0.93      0.90      0.90        30
